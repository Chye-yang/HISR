# %% [markdown]
# # HISR脚本执行Notebook
# 本Notebook用于依次运行关键脚本实现示例目录下的Python脚本

# %%
import os
import subprocess

# 设置工作目录为脚本所在目录
os.chdir(os.path.dirname(os.path.abspath(__file__)))

# %% [markdown]
# ## 1. 运行bucketize.py

# %%
# !python bucketize.py

# %% [markdown]
# ## 2. 运行decoder_prefix_tree.py

# %%
# !python decoder_prefix_tree.py

# %% [markdown]
# ## 3. 运行encoder_bipartite.py

# %%
# !python encoder_bipartite.py

# %% [markdown]
# ## 4. 运行local_operator.py

# %%
# !python local_operator.py

# %% [markdown]
# ## 5. 运行prefix.py

# %%
# !python prefix.py

# %% [markdown]
# ## 6. 运行train_eval_hisr.py

# %%
# !python train_eval_hisr.py
